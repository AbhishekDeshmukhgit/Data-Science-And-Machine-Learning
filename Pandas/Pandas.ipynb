# %%
import pandas as pd

# %% [markdown]
# #Series=1-Dimensional

# %%
color=pd.Series(["Red","White","Green"]);
color
# Out:
# 0      Red
# 1    White
# 2    Green
# dtype: object

# %%
car=pd.Series(["BMW","Tesla","Audi"])

# %%
#Dataframe=2_dimensional
c=pd.DataFrame({"carname":car,"colorname":color});
c
# Out:
#   carname colorname
# 0     BMW       Red
# 1   Tesla     White
# 2    Audi     Green

# %% [markdown]
# #Read CSV

# %%
carsales=pd.read_csv("car-sales.csv")
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
carsales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
carsales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carsales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
len(carsales)
# Out:
# 10

# %% [markdown]
# ## Viewing And Selecting Data

# %%
carsales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
carsales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
carsales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
pd.crosstab(carsales["Make"],carsales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Group BY
carsales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
carsales["Doors"].plot()
# Out:
# <AxesSubplot:>

# %%
carsales["Doors"].hist()
# Out:
# <AxesSubplot:>

# %%
carsales["Price"]=carsales["Price"].str.replace('[\$\,\.]','').astype(int)
# Out:
# C:\Users\Wings\AppData\Local\Temp\ipykernel_2580\506038482.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   carsales["Price"]=carsales["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
carsales["Price"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulating Data

# %%
carsales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carsales["Make"]=carsales["Make"].str.lower()
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
carmissing=pd.read_csv("carmissing-data.csv")

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
carmissing["Odometer"].fillna(carmissing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
carmissing["Odometer"].fillna(carmissing["Odometer"].mean(),inplace=True)

# %%
carmissing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
carmissing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
#Column from series
seatcol=pd.Series([5,5,5,5,5])
seatcol
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
#New colummn called Seat
carmissing["Seat"]=seatcol
carmissing
# Out:
#      Make Colour       Odometer  Doors    Price  Seat
# 0  Toyota  White  150043.000000    4.0   $4,000   5.0
# 1   Honda    Red   87899.000000    4.0   $5,000   5.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000   5.0
# 3     BMW  Black   11179.000000    5.0  $22,000   5.0
# 4  Nissan  White  213095.000000    4.0   $3,500   5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500   NaN

# %%
carmissing.fillna(5,inplace=True)
carmissing
# Out:
#      Make Colour       Odometer  Doors    Price  Seat
# 0  Toyota  White  150043.000000    4.0   $4,000   5.0
# 1   Honda    Red   87899.000000    4.0   $5,000   5.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000   5.0
# 3     BMW  Black   11179.000000    5.0  $22,000   5.0
# 4  Nissan  White  213095.000000    4.0   $3,500   5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500   5.0

# %%
#Column from python list
fueleconomy=[5,6,7,3,2,10]
carmissing["Fuel per 100 Km"]=fueleconomy
carmissing
# Out:
#      Make Colour       Odometer  Doors    Price  Seat  Fuel  Fuel per 100 Km
# 0  Toyota  White  150043.000000    4.0   $4,000   5.0     5                5
# 1   Honda    Red   87899.000000    4.0   $5,000   5.0     6                6
# 2  Toyota   Blue   92302.666667    3.0   $7,000   5.0     7                7
# 3     BMW  Black   11179.000000    5.0  $22,000   5.0     3                3
# 4  Nissan  White  213095.000000    4.0   $3,500   5.0     2                2
# 5  Toyota  Green   92302.666667    4.0   $4,500   5.0    10               10

# %%
carmissing["Total fuel used"]=carmissing["Odometer"]/100*carmissing["Fuel per 100 Km"]

# %%
carmissing
# Out:
#      Make Colour       Odometer  Doors    Price  Seat  Fuel  Fuel per 100 Km  \
# 0  Toyota  White  150043.000000    4.0   $4,000   5.0     5                5
# 1   Honda    Red   87899.000000    4.0   $5,000   5.0     6                6
# 2  Toyota   Blue   92302.666667    3.0   $7,000   5.0     7                7
# 3     BMW  Black   11179.000000    5.0  $22,000   5.0     3                3
# 4  Nissan  White  213095.000000    4.0   $3,500   5.0     2                2
# 5  Toyota  Green   92302.666667    4.0   $4,500   5.0    10               10
#
#    Total fuel used
# 0      7502.150000
# 1      5273.940000
# 2      6461.186667
# 3       335.370000
# 4      4261.900000
# 5      9230.266667

# %%
carmissing["Number of Wheel"]=4
carmissing.dtypes
# Out:
# Make                object
# Colour              object
# Odometer           float64
# Doors              float64
# Price               object
# Seat               float64
# Fuel                 int64
# Fuel per 100 Km      int64
# Total fuel used    float64
# Number of Wheel      int64
# dtype: object

# %%
carmissing
# Out:
#      Make Colour       Odometer  Doors    Price  Seat  Fuel per 100 Km  \
# 0  Toyota  White  150043.000000    4.0   $4,000   5.0                5
# 1   Honda    Red   87899.000000    4.0   $5,000   5.0                6
# 2  Toyota   Blue   92302.666667    3.0   $7,000   5.0                7
# 3     BMW  Black   11179.000000    5.0  $22,000   5.0                3
# 4  Nissan  White  213095.000000    4.0   $3,500   5.0                2
# 5  Toyota  Green   92302.666667    4.0   $4,500   5.0               10
#
#    Total fuel used  Number of Wheel
# 0      7502.150000                4
# 1      5273.940000                4
# 2      6461.186667                4
# 3       335.370000                4
# 4      4261.900000                4
# 5      9230.266667                4

# %%
carmissing.drop("Fuel",axis=1,inplace=True)

# %%
#Shuffle Dataframe[frac is used to select specefic data]
carmissing.sample(frac=1)
# Out:
#      Make Colour       Odometer  Doors    Price  Seat  Fuel per 100 Km  \
# 3     BMW  Black   11179.000000    5.0  $22,000   5.0                3
# 0  Toyota  White  150043.000000    4.0   $4,000   5.0                5
# 4  Nissan  White  213095.000000    4.0   $3,500   5.0                2
# 1   Honda    Red   87899.000000    4.0   $5,000   5.0                6
# 2  Toyota   Blue   92302.666667    3.0   $7,000   5.0                7
# 5  Toyota  Green   92302.666667    4.0   $4,500   5.0               10
#
#    Total fuel used  Number of Wheel
# 3       335.370000                4
# 0      7502.150000                4
# 4      4261.900000                4
# 1      5273.940000                4
# 2      6461.186667                4
# 5      9230.266667                4

# %%
# convert the km into miles
carmissing["Odometer"]=carmissing["Odometer"].apply(lambda x: x / 1.6)
carmissing
